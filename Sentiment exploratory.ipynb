# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tweets = pd.read_csv('train.csv')

# %%
tweets.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
# textID           27481 non-null object
# text             27480 non-null object
# selected_text    27480 non-null object
# sentiment        27481 non-null object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %%
sns.countplot(tweets['sentiment'])

# %%
single_sel_txt = tweets.loc[0,'selected_text']
single_txt = tweets.loc[0,'text']

# %%
single_sel_txt
# Out:
# 'I`d have responded, if I were going'

# %%
single_txt
# Out:
# ' I`d have responded, if I were going'

# %%
tweets['selected_text eq text'] = tweets.apply(lambda x: x.text == x.selected_text, axis=1)

# %%
tweets.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  selected_text eq text
# 0  I`d have responded, if I were going   neutral                  False
# 1                             Sooo SAD  negative                  False
# 2                          bullying me  negative                  False
# 3                       leave me alone  negative                  False
# 4                        Sons of ****,  negative                  False

# %%
sns.countplot(tweets['sentiment'], hue=tweets['selected_text eq text'])

# %%
tweets[np.logical_and(tweets['sentiment'] == 'neutral', tweets['selected_text eq text'] == False)].head(20)
# Out:
#         textID                                               text  \
# 0   cb774db0d1                I`d have responded, if I were going
# 8   e050245fbd                                        Both of you
# 10  2339a9b08b   as much as i love to be hopeful, i reckon the...
# 20  04d17ef61e   oh Marly, I`m so sorry!!  I hope you find her...
# 34  d21ab5855b   Ahhh, I slept through the game.  I`m gonna tr...
# 35  4f5267ad70  Thats it, its the end. Tears for Fears vs Eric...
# 40  d93afa85cf   Car not happy, big big dent in boot! Hoping t...
# 50  a3ae670885   Then you should check out http://twittersucks...
# 51  15d5f3a41b   also bored at school, its my third freelesson...
# 52  3c4a21b2cb                        hm... Both of us I guess...
# 55  e77fd45003   I`d rather do the early run..but I am a morni...
# 57  6086b1f016      will be back later.  http://plurk.com/p/rp3k7
# 59  90f3d2b572                      what fun are you speaking of?
# ...

# %%
tweets[np.logical_and(tweets['sentiment'] == 'positive', tweets['selected_text eq text'] == True)].head(20)
# Out:
#          textID                                               text  \
# 25   e00c6ef376  the free fillin` app on my ipod is fun, im add...
# 68   fa2654e730                                           Chilliin
# 85   3d2fcd78c8  Happy Star Wars day everyone! and Enjoy the ho...
# 95   4c41a35a2a        Happy Mothers day to all you Mums out there
# 190  9b11b686ec                                   happy 1 year! <3
# 264  97334eb7c0  Well good morning all, What a wonderful day in...
# 283  80481307d5  Happy Mothers Day people. i love my mom a lot ...
# 300  7b69f49c42          tonight in party w/ my girls (minus vita)
# 322  ea3320d696  Before I get too distracted, I`d like to thank...
# 363  95d0ad2e17                                aww  you loooove me
# 365  39923bb286                                  awesome lucky you
# 377  3773846bc3  Omg Wango Tango was **** AWSOME! I love my bab...
# 430  a78ef3e0d0                                        Goodmorning
# ...

# %%
tweets[np.logical_and(tweets['sentiment'] == 'negative', tweets['selected_text eq text'] == True)].head(20)
# Out:
#          textID                                               text  \
# 15   8a939bfb59                              Uh oh, I am sunburned
# 62   2a9765b7f9                                I give in to easily
# 78   0a61cbf4b5                                    I am sooo tired
# 124  f0460d611d                                           not well
# 144  7e4ed52c4a                                      Hate fighting
# 146  48cdcd5f28          Car-warmed Sprite tastes like sore throat
# 158  5f93cc70ff  Bugger. forgot I still have washing in my machine
# 218  a8734230b6                                         Ew traffic
# 288  ba83f744d8  You know your neck is jacked up when you are f...
# 311  c4ab28566e                                   Ship. I`m stuck.
# 329  0404648e1c                                         ?sucks!?..
# 334  f1f5e8edfa                             I Miss Daddy and Mommy
# 393  5fcf7bd80c                             My sunburn is peeling,
# ...

# %%
repeated_selected_texts = tweets['selected_text'].apply(lambda x: x.lower()).value_counts()
repeated_selected_texts.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-66da5b3894fe> in <module>
# ----> 1 repeated_selected_texts = tweets['selected_text'].apply(lambda x: x.lower()).value_counts()
#       2 repeated_selected_texts.head(20)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-33-66da5b3894fe> in <lambda>(x)
# ----> 1 repeated_selected_texts = tweets['selected_text'].apply(lambda x: x.lower()).value_counts()
#       2 repeated_selected_texts.head(20)
#
# ...

# %%
tweets['selected_text'].apply(type).value_counts()
# Out:
# <class 'str'>      27480
# <class 'float'>        1
# Name: selected_text, dtype: int64

# %%
na_value = tweets[tweets.isna().any(axis=1)]

# %%
na_value
# Out:
#          textID text selected_text sentiment  selected_text eq text
# 314  fdb77c3752  NaN           NaN   neutral                  False

# %%
tweets = tweets.dropna()

# %%
repeated_selected_texts = tweets['selected_text'].apply(lambda x: x.lower()).value_counts()
repeated_selected_texts.head(20)
# Out:
# happy      303
# good       262
# love       230
# thanks     182
# miss       151
# great      114
# sorry      114
# sad        106
# hate        81
# nice        80
# hope        76
# fun         74
# wish        68
# awesome     68
# bad         68
# ****        63
# best        50
# sick        48
# glad        47
# tired       47
# Name: selected_text, dtype: int64

# %%
repeated_pos = tweets[tweets['sentiment'] == 'positive']['selected_text'].apply(lambda x: x.lower()).value_counts()
repeated_neg = tweets[tweets['sentiment'] == 'negative']['selected_text'].apply(lambda x: x.lower()).value_counts()

# %%
repeated_pos.head(5)
# Out:
# happy     302
# good      261
# love      230
# thanks    182
# great     112
# Name: selected_text, dtype: int64

# %%
repeated_neg.head(5)
# Out:
# miss     151
# sorry    113
# sad      106
# hate      80
# bad       67
# Name: selected_text, dtype: int64

# %%
tweets['has_asterisk'] = tweets['text'].apply(lambda x: '*' in x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(tweets[tweets['has_asterisk'] == True].shape)
tweets[tweets['has_asterisk'] == True].head(10)
# Out:
# (1309, 7)
#          textID                                               text  \
# 4    358bd9e861   Sons of ****, why couldn`t they put them on t...
# 16   3440297f8b   S`ok, trying to plot alternatives as we speak...
# 30   d33f811375  I`m going home now. Have you seen my new twitt...
# 41   fab6b7d16c  im an avid fan of **** magazine and i love you...
# 53   11084dac09   it is ****...u have dissappointed me that pas...
# 92   a3de81e1ba   Hi  how are you doing ???  *just joined twitt...
# 107  40649553ef   haha I do not know how to work blip apart fro...
# 176  557e676fe4   I miss my neice  can`t wait to see her bad n ...
# 192  28dbada620   *phew*  Will make a note in case anyone else ...
# 203  58c435d2cf                        more nightmares?  *huggles*
#
#                                          selected_text sentiment  \
# 4                                        Sons of ****,  negative
# 16                                              *sigh*  negative
# ...

# %%
tweets['has_4asterisks'] = tweets['text'].apply(lambda x: '****' in x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(tweets[tweets['has_4asterisks'] == True].shape)
tweets[tweets['has_4asterisks'] == True].head(10)
# Out:
# (1000, 7)
#          textID                                               text  \
# 4    358bd9e861   Sons of ****, why couldn`t they put them on t...
# 30   d33f811375  I`m going home now. Have you seen my new twitt...
# 41   fab6b7d16c  im an avid fan of **** magazine and i love you...
# 53   11084dac09   it is ****...u have dissappointed me that pas...
# 107  40649553ef   haha I do not know how to work blip apart fro...
# 176  557e676fe4   I miss my neice  can`t wait to see her bad n ...
# 204  e6ee6826df  I AM SUCH A CREEPER  I feel disappointed becau...
# 248  6402e14398  Wolverine Was BOSS! Seriously, And Will.I.Am W...
# 254  c5645758be  Trying to decide on a movie with the friends.....
# 272  52d8be9124   huh what the ****? Smelly? Noooo. I love alex...
#
#                                          selected_text sentiment  \
# 4                                        Sons of ****,  negative
# 30                                   Quite....heavenly  positive
# ...

# %%
tweets.loc[30, 'text']
# Out:
# 'I`m going home now. Have you seen my new twitter design? Quite....heavenly isn`****?'
